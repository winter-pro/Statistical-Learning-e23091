# %% [markdown]
# # Energy Analysis Assignment
#
# Gaussian Process Regression and Linear Regression assignment notebook.

# %%
# !pip install kagglehub pandas numpy matplotlib scikit-learn

# %% [markdown]
# ## Run Gaussian Process Regression

# %%
# !python src/gp_energy_efficiency.py

# %% [markdown]
# ## Run Linear Regression

# %%
# !python src/linear_green_building.py
